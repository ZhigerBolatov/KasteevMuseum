# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, average_precision_score, f1_score

# Параметры
batch_size = 16
img_size = (224, 224)
epochs = 300
data_path = "/content/drive/MyDrive/yolo/croped_dataset_train"

# Проверка и балансировка классов
class_counts = {class_name: len(os.listdir(os.path.join(data_path, class_name)))
                for class_name in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, class_name))}
print("Распределение классов:", class_counts)

# Генерация данных с аугментацией
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)

train_generator = train_datagen.flow_from_directory(
    data_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='training',
    shuffle=True
)

validation_generator = train_datagen.flow_from_directory(
    data_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',
    shuffle=False
)

num_classes = len(train_generator.class_indices)

# Создание модели MobileNetV3Small
base_model = EfficientNetV2S(include_top=False, input_shape=(img_size[0], img_size[1], 3), weights='imagenet')
base_model.trainable = True

for layer in base_model.layers[:-50]:  # Размораживаем верхние 50 слоев
    layer.trainable = False

model = models.Sequential([
    base_model,
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.8),
    layers.Dense(num_classes, activation='softmax', kernel_regularizer=regularizers.l2(0.01))
])

model.compile(
    optimizer=Adam(learning_rate=2e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

# Обучение модели
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[reduce_lr, early_stopping]
)

# Классы и индексы
class_indices = train_generator.class_indices
inverted_class_indices = {v: k for k, v in class_indices.items()}

# Сохранение модели
keras_model_path = "/content/drive/MyDrive/yolo/models/EfficientNetV2/EfficientNetV2S.keras"
model.save(keras_model_path)
print(f"Модель сохранена в формате Keras: {keras_model_path}")

# Конвертация модели в TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
#converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Оптимизация модели
tflite_model = converter.convert()

# Сохранение TFLite модели
tflite_model_path = "/content/drive/MyDrive/yolo/models/EfficientNetV2/EfficientNetV2S.tflite"
with open(tflite_model_path, "wb") as f:
    f.write(tflite_model)

print(f"Модель успешно сохранена в формате TFLite: {tflite_model_path}")

# Вычисление метрик на валидационном наборе
y_true = validation_generator.classes
y_pred_probs = model.predict(validation_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix (нормализованная)
cm = confusion_matrix(y_true, y_pred, normalize='true')
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=False, cmap='Blues')
plt.title("Confusion Matrix Normalized")
plt.xlabel("True")
plt.ylabel("Predicted")
plt.show()

# Precision, Recall, F1-score
report = classification_report(y_true, y_pred, target_names=list(class_indices.keys()))
print(report)

# F1-Confidence Curve
confidence_levels = np.linspace(0, 1, 100)
f1_scores = []

for conf in confidence_levels:
    filtered_preds = np.where(y_pred_probs.max(axis=1) >= conf, y_pred, -1)
    f1 = f1_score(y_true, filtered_preds, average='macro', zero_division=0)
    f1_scores.append(f1)

plt.figure(figsize=(8, 6))
plt.plot(confidence_levels, f1_scores, label=f'F1-score (max {max(f1_scores):.2f} at {confidence_levels[np.argmax(f1_scores)]:.3f})', color='blue')
plt.xlabel("Confidence")
plt.ylabel("F1-score")
plt.title("F1-Confidence Curve")
plt.legend()
plt.show()

# Mean Average Precision at IoU=0.5 и IoU=0.5:0.95
average_precisions = []
for i in range(num_classes):
    precision, recall, _ = precision_recall_curve(y_true == i, y_pred_probs[:, i])
    ap = average_precision_score(y_true == i, y_pred_probs[:, i])
    average_precisions.append(ap)

map_50 = np.mean(average_precisions)
map_50_95 = np.mean([ap for ap in average_precisions if ap > 0.05])  # Исключаем слишком малые значения

print(f"Mean Average Precision at IoU=0.5: {map_50:.4f}")
print(f"Mean Average Precision at IoU=0.5:0.95: {map_50_95:.4f}")
# Out:
# Распределение классов: {'0_verblyud_skulptura': 161, '18_ukrasheniya': 99, '17_gobelen_ornament_alasha': 148, '14_sedlo1': 143, '10_posuda_dlya_kumisa': 305, '19_fancy_vaza': 200, '15_sedlo2': 123, '1_barashek': 193, '13_dombri': 252, '16_kobiz_vaza_gobelen': 167, '12_sandyk1': 143, '26_berkutchi_s_ptichey': 140, '27_turksib': 124, '25_voylok_na_kruge_abstract': 192, '20_yarkiy_gobelen_ledi': 195, '21_mujchina_s_mechom': 160, '23_revolyuchiya_v_aule': 60, '24_dekorativniyi_vazi_vmeste': 237, '29_vesna_jaylau_zagatovka_productov': 119, '22_jambyl': 149, '28_shokan_sidit': 137, '33_medeu': 60, '36_gobelen_derevo': 252, '30_senokos': 138, '34_ges': 60, '2_tri_skulpturi_s_sharami': 303, '35_vitrina_s_ukrasheniyami': 60, '31_gori_i_voda': 55, '38_gobelen_krasniy': 60, '32_mujchina_s_gazetoy': 58, '48_Mullashev_triptih': 186, '40_Abishev_klich': 112, '3_chernaya_vaza': 162, '41_Aytbayev_schaste': 157, '45_Esirkeev_zvuki_kobiza': 146, '43_Dosmogambetov_Suleymenov': 103, '44_Esenbayev_Saule': 112, '42_Ahmetov_kompoziciya_4': 153, '39_loshadki_na_jaylau': 149, '46_Jumabay_tri_mecha': 149, '50_Sydyhanov_verbludica': 135, '5_barashki_pasutsya': 164, '9_burdyuk_otdelno': 60, '4_saukele': 130, '8_cvetushaya_yablonya': 20, '49_Prokopeva_Sulemenov': 130, '6_vaza_otdelno': 40, '7_halat': 60, '37_gobelen_shahmati': 225}
# Found 5525 images belonging to 49 classes.
# Found 1361 images belonging to 49 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 6056s 17s/step - accuracy: 0.0689 - loss: 4.5498 - val_accuracy: 0.2873 - val_loss: 3.4066 - learning_rate: 2.0000e-04
# Epoch 2/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 435ms/step - accuracy: 0.2200 - loss: 3.5407 - val_accuracy: 0.4269 - val_loss: 2.6272 - learning_rate: 2.0000e-04
# Epoch 3/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 432ms/step - accuracy: 0.3206 - loss: 3.0100 - val_accuracy: 0.5298 - val_loss: 2.2739 - learning_rate: 2.0000e-04
# Epoch 4/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.3918 - loss: 2.6563 - val_accuracy: 0.5768 - val_loss: 1.9588 - learning_rate: 2.0000e-04
# Epoch 5/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 437ms/step - accuracy: 0.4489 - loss: 2.3916 - val_accuracy: 0.5805 - val_loss: 1.8856 - learning_rate: 2.0000e-04
# Epoch 6/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 432ms/step - accuracy: 0.5054 - loss: 2.2073 - val_accuracy: 0.6223 - val_loss: 1.7328 - learning_rate: 2.0000e-04
# Epoch 7/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.5497 - loss: 2.0068 - val_accuracy: 0.6679 - val_loss: 1.5834 - learning_rate: 2.0000e-04
# Epoch 8/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.5589 - loss: 1.9520 - val_accuracy: 0.6760 - val_loss: 1.5171 - learning_rate: 2.0000e-04
# Epoch 9/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 149s 431ms/step - accuracy: 0.5801 - loss: 1.8407 - val_accuracy: 0.6525 - val_loss: 1.5475 - learning_rate: 2.0000e-04
# Epoch 10/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.5933 - loss: 1.7536 - val_accuracy: 0.6995 - val_loss: 1.4065 - learning_rate: 2.0000e-04
# Epoch 11/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.6115 - loss: 1.6917 - val_accuracy: 0.7032 - val_loss: 1.4049 - learning_rate: 2.0000e-04
# Epoch 12/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.6199 - loss: 1.6674 - val_accuracy: 0.7333 - val_loss: 1.2829 - learning_rate: 2.0000e-04
# Epoch 13/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 149s 432ms/step - accuracy: 0.6415 - loss: 1.5832 - val_accuracy: 0.7399 - val_loss: 1.2420 - learning_rate: 2.0000e-04
# Epoch 14/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.6449 - loss: 1.5491 - val_accuracy: 0.7362 - val_loss: 1.2044 - learning_rate: 2.0000e-04
# Epoch 15/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 435ms/step - accuracy: 0.6552 - loss: 1.4960 - val_accuracy: 0.7627 - val_loss: 1.1289 - learning_rate: 2.0000e-04
# Epoch 16/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 149s 430ms/step - accuracy: 0.6773 - loss: 1.4470 - val_accuracy: 0.7237 - val_loss: 1.2420 - learning_rate: 2.0000e-04
# Epoch 17/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 149s 432ms/step - accuracy: 0.6848 - loss: 1.4072 - val_accuracy: 0.7392 - val_loss: 1.1572 - learning_rate: 2.0000e-04
# Epoch 18/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 149s 432ms/step - accuracy: 0.6764 - loss: 1.4189 - val_accuracy: 0.7509 - val_loss: 1.1183 - learning_rate: 2.0000e-04
# Epoch 19/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.6900 - loss: 1.3843 - val_accuracy: 0.7583 - val_loss: 1.1121 - learning_rate: 2.0000e-04
# Epoch 20/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 435ms/step - accuracy: 0.7009 - loss: 1.3093 - val_accuracy: 0.7730 - val_loss: 1.0684 - learning_rate: 2.0000e-04
# Epoch 21/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7080 - loss: 1.2877 - val_accuracy: 0.7686 - val_loss: 1.0826 - learning_rate: 2.0000e-04
# Epoch 22/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 436ms/step - accuracy: 0.7117 - loss: 1.2599 - val_accuracy: 0.7575 - val_loss: 1.1161 - learning_rate: 2.0000e-04
# Epoch 23/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.7128 - loss: 1.2425 - val_accuracy: 0.7553 - val_loss: 1.0844 - learning_rate: 2.0000e-04
# Epoch 24/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 435ms/step - accuracy: 0.7118 - loss: 1.2454 - val_accuracy: 0.7708 - val_loss: 1.0527 - learning_rate: 2.0000e-04
# Epoch 25/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.7233 - loss: 1.2462 - val_accuracy: 0.7818 - val_loss: 1.0550 - learning_rate: 2.0000e-04
# Epoch 26/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7341 - loss: 1.2070 - val_accuracy: 0.7862 - val_loss: 0.9912 - learning_rate: 2.0000e-04
# Epoch 27/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.7089 - loss: 1.2511 - val_accuracy: 0.7781 - val_loss: 1.0527 - learning_rate: 2.0000e-04
# Epoch 28/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7423 - loss: 1.1489 - val_accuracy: 0.7855 - val_loss: 0.9943 - learning_rate: 2.0000e-04
# Epoch 29/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7435 - loss: 1.1583 - val_accuracy: 0.8075 - val_loss: 0.9446 - learning_rate: 2.0000e-04
# Epoch 30/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.7559 - loss: 1.1184 - val_accuracy: 0.8024 - val_loss: 0.9546 - learning_rate: 2.0000e-04
# Epoch 31/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7519 - loss: 1.1149 - val_accuracy: 0.7832 - val_loss: 0.9839 - learning_rate: 2.0000e-04
# Epoch 32/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 437ms/step - accuracy: 0.7523 - loss: 1.1052 - val_accuracy: 0.7877 - val_loss: 0.9305 - learning_rate: 2.0000e-04
# Epoch 33/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 151s 435ms/step - accuracy: 0.7551 - loss: 1.1153 - val_accuracy: 0.8112 - val_loss: 0.8908 - learning_rate: 2.0000e-04
# Epoch 34/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 150s 434ms/step - accuracy: 0.7539 - loss: 1.1089 - val_accuracy: 0.8068 - val_loss: 0.8991 - learning_rate: 2.0000e-04
# Epoch 35/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.7604 - loss: 1.0803 - val_accuracy: 0.8068 - val_loss: 0.9606 - learning_rate: 2.0000e-04
# Epoch 36/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.7552 - loss: 1.0715 - val_accuracy: 0.8082 - val_loss: 0.9272 - learning_rate: 2.0000e-04
# Epoch 37/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.7665 - loss: 1.0633 - val_accuracy: 0.8068 - val_loss: 0.8985 - learning_rate: 2.0000e-04
# Epoch 38/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.7749 - loss: 1.0159 - val_accuracy: 0.8038 - val_loss: 0.9322 - learning_rate: 2.0000e-04
# Epoch 39/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.7822 - loss: 1.0076 - val_accuracy: 0.8251 - val_loss: 0.8390 - learning_rate: 1.0000e-04
# Epoch 40/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.7999 - loss: 0.9336 - val_accuracy: 0.8156 - val_loss: 0.8647 - learning_rate: 1.0000e-04
# Epoch 41/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 415ms/step - accuracy: 0.7958 - loss: 0.9478 - val_accuracy: 0.8229 - val_loss: 0.8602 - learning_rate: 1.0000e-04
# Epoch 42/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 418ms/step - accuracy: 0.8044 - loss: 0.9230 - val_accuracy: 0.8141 - val_loss: 0.8574 - learning_rate: 1.0000e-04
# Epoch 43/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 418ms/step - accuracy: 0.7980 - loss: 0.9181 - val_accuracy: 0.8325 - val_loss: 0.8292 - learning_rate: 1.0000e-04
# Epoch 44/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8100 - loss: 0.9066 - val_accuracy: 0.8369 - val_loss: 0.8058 - learning_rate: 1.0000e-04
# Epoch 45/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8061 - loss: 0.8771 - val_accuracy: 0.8170 - val_loss: 0.8685 - learning_rate: 1.0000e-04
# Epoch 46/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 418ms/step - accuracy: 0.8078 - loss: 0.9005 - val_accuracy: 0.8163 - val_loss: 0.8309 - learning_rate: 1.0000e-04
# Epoch 47/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8076 - loss: 0.8818 - val_accuracy: 0.8288 - val_loss: 0.8174 - learning_rate: 1.0000e-04
# Epoch 48/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8093 - loss: 0.8911 - val_accuracy: 0.8406 - val_loss: 0.7464 - learning_rate: 1.0000e-04
# Epoch 49/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 418ms/step - accuracy: 0.8010 - loss: 0.8930 - val_accuracy: 0.8589 - val_loss: 0.7077 - learning_rate: 1.0000e-04
# Epoch 50/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8121 - loss: 0.8470 - val_accuracy: 0.8376 - val_loss: 0.7765 - learning_rate: 1.0000e-04
# Epoch 51/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8104 - loss: 0.8665 - val_accuracy: 0.8428 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 52/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 418ms/step - accuracy: 0.8162 - loss: 0.8613 - val_accuracy: 0.8479 - val_loss: 0.7427 - learning_rate: 1.0000e-04
# Epoch 53/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8040 - loss: 0.8724 - val_accuracy: 0.8215 - val_loss: 0.8179 - learning_rate: 1.0000e-04
# Epoch 54/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8278 - loss: 0.8200 - val_accuracy: 0.8339 - val_loss: 0.7700 - learning_rate: 1.0000e-04
# Epoch 55/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 415ms/step - accuracy: 0.8143 - loss: 0.8602 - val_accuracy: 0.8413 - val_loss: 0.7682 - learning_rate: 5.0000e-05
# Epoch 56/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8270 - loss: 0.8186 - val_accuracy: 0.8361 - val_loss: 0.7448 - learning_rate: 5.0000e-05
# Epoch 57/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8143 - loss: 0.8551 - val_accuracy: 0.8494 - val_loss: 0.7044 - learning_rate: 5.0000e-05
# Epoch 58/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8332 - loss: 0.7625 - val_accuracy: 0.8420 - val_loss: 0.7149 - learning_rate: 5.0000e-05
# Epoch 59/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 147s 423ms/step - accuracy: 0.8300 - loss: 0.7911 - val_accuracy: 0.8582 - val_loss: 0.6554 - learning_rate: 5.0000e-05
# Epoch 60/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 147s 425ms/step - accuracy: 0.8342 - loss: 0.7784 - val_accuracy: 0.8560 - val_loss: 0.7029 - learning_rate: 5.0000e-05
# Epoch 61/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.8225 - loss: 0.7880 - val_accuracy: 0.8428 - val_loss: 0.7469 - learning_rate: 5.0000e-05
# Epoch 62/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8297 - loss: 0.7897 - val_accuracy: 0.8611 - val_loss: 0.6829 - learning_rate: 5.0000e-05
# Epoch 63/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8371 - loss: 0.7726 - val_accuracy: 0.8589 - val_loss: 0.6894 - learning_rate: 5.0000e-05
# Epoch 64/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8411 - loss: 0.7457 - val_accuracy: 0.8648 - val_loss: 0.6711 - learning_rate: 5.0000e-05
# Epoch 65/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8388 - loss: 0.7409 - val_accuracy: 0.8619 - val_loss: 0.6690 - learning_rate: 2.5000e-05
# Epoch 66/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.8537 - loss: 0.7159 - val_accuracy: 0.8575 - val_loss: 0.6685 - learning_rate: 2.5000e-05
# Epoch 67/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8378 - loss: 0.7208 - val_accuracy: 0.8486 - val_loss: 0.7073 - learning_rate: 2.5000e-05
# Epoch 68/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8430 - loss: 0.7349 - val_accuracy: 0.8604 - val_loss: 0.6826 - learning_rate: 2.5000e-05
# Epoch 69/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 146s 421ms/step - accuracy: 0.8472 - loss: 0.7396 - val_accuracy: 0.8589 - val_loss: 0.6909 - learning_rate: 2.5000e-05
# Epoch 70/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 420ms/step - accuracy: 0.8377 - loss: 0.7515 - val_accuracy: 0.8611 - val_loss: 0.6444 - learning_rate: 1.2500e-05
# Epoch 71/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 420ms/step - accuracy: 0.8430 - loss: 0.7220 - val_accuracy: 0.8589 - val_loss: 0.6811 - learning_rate: 1.2500e-05
# Epoch 72/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 418ms/step - accuracy: 0.8485 - loss: 0.7251 - val_accuracy: 0.8567 - val_loss: 0.6593 - learning_rate: 1.2500e-05
# Epoch 73/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.8486 - loss: 0.7243 - val_accuracy: 0.8589 - val_loss: 0.6735 - learning_rate: 1.2500e-05
# Epoch 74/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 420ms/step - accuracy: 0.8449 - loss: 0.7225 - val_accuracy: 0.8736 - val_loss: 0.6420 - learning_rate: 1.2500e-05
# Epoch 75/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 146s 421ms/step - accuracy: 0.8453 - loss: 0.7147 - val_accuracy: 0.8780 - val_loss: 0.6552 - learning_rate: 1.2500e-05
# Epoch 76/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 418ms/step - accuracy: 0.8464 - loss: 0.7293 - val_accuracy: 0.8722 - val_loss: 0.6529 - learning_rate: 1.2500e-05
# Epoch 77/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 420ms/step - accuracy: 0.8611 - loss: 0.6943 - val_accuracy: 0.8685 - val_loss: 0.6801 - learning_rate: 1.2500e-05
# Epoch 78/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 146s 422ms/step - accuracy: 0.8507 - loss: 0.7098 - val_accuracy: 0.8648 - val_loss: 0.6703 - learning_rate: 1.2500e-05
# Epoch 79/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.8430 - loss: 0.7171 - val_accuracy: 0.8663 - val_loss: 0.6573 - learning_rate: 1.2500e-05
# Epoch 80/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 418ms/step - accuracy: 0.8550 - loss: 0.6907 - val_accuracy: 0.8655 - val_loss: 0.6425 - learning_rate: 6.2500e-06
# Epoch 81/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8607 - loss: 0.6732 - val_accuracy: 0.8744 - val_loss: 0.6455 - learning_rate: 6.2500e-06
# Epoch 82/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8637 - loss: 0.6787 - val_accuracy: 0.8648 - val_loss: 0.6794 - learning_rate: 6.2500e-06
# Epoch 83/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8383 - loss: 0.7261 - val_accuracy: 0.8788 - val_loss: 0.5961 - learning_rate: 6.2500e-06
# Epoch 84/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8493 - loss: 0.7210 - val_accuracy: 0.8670 - val_loss: 0.6442 - learning_rate: 6.2500e-06
# Epoch 85/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8591 - loss: 0.6634 - val_accuracy: 0.8655 - val_loss: 0.6665 - learning_rate: 6.2500e-06
# Epoch 86/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 145s 419ms/step - accuracy: 0.8516 - loss: 0.7126 - val_accuracy: 0.8663 - val_loss: 0.6709 - learning_rate: 6.2500e-06
# Epoch 87/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 416ms/step - accuracy: 0.8627 - loss: 0.6722 - val_accuracy: 0.8699 - val_loss: 0.6613 - learning_rate: 6.2500e-06
# Epoch 88/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8541 - loss: 0.6922 - val_accuracy: 0.8604 - val_loss: 0.6792 - learning_rate: 6.2500e-06
# Epoch 89/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.8538 - loss: 0.7008 - val_accuracy: 0.8729 - val_loss: 0.6246 - learning_rate: 3.1250e-06
# Epoch 90/300
# 346/346 ━━━━━━━━━━━━━━━━━━━━ 144s 417ms/step - accuracy: 0.
TensorSpec(shape=(), dtype=tf.resource, name=None)
# Модель успешно сохранена в формате TFLite: /content/drive/MyDrive/yolo/models/EfficientNetV2/EfficientNetV2S.tflite
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 48s 445ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                      precision    recall  f1-score   support
#
#                0_verblyud_skulptura       0.49      0.66      0.56        32
#               10_posuda_dlya_kumisa       0.75      0.75      0.75        61
#                          12_sandyk1       1.00      1.00      1.00        28
#                           13_dombri       0.87      0.90      0.88        50
#                           14_sedlo1       1.00      1.00      1.00        28
#                           15_sedlo2       0.96      1.00      0.98        24
#               16_kobiz_vaza_gobelen       0.80      0.61      0.69        33
#          17_gobelen_ornament_alasha       1.00      1.00      1.00        29
#                      18_ukrasheniya       0.89      0.89      0.89        19
#                       19_fancy_vaza       0.91      0.97      0.94        40
#                          1_barashek       0.67      0.74      0.70        38
#              20_yarkiy_gobelen_ledi       1.00      1.00      1.00        39
#                21_mujchina_s_mechom       1.00      1.00      1.00        32
#                           22_jambyl       1.00      1.00      1.00        29
#              23_revolyuchiya_v_aule       0.92      1.00      0.96        12
#        24_dekorativniyi_vazi_vmeste       0.72      0.62      0.67        47
#         25_voylok_na_kruge_abstract       1.00      1.00      1.00        38
#              26_berkutchi_s_ptichey       1.00      1.00      1.00        28
#                          27_turksib       0.90      0.79      0.84        24
#                     28_shokan_sidit       0.92      0.81      0.86        27
# 29_vesna_jaylau_zagatovka_productov       0.80      0.70      0.74        23
#           2_tri_skulpturi_s_sharami       0.85      0.85      0.85        60
#                          30_senokos       1.00      0.96      0.98        27
#                      31_gori_i_voda       0.92      1.00      0.96        11
#               32_mujchina_s_gazetoy       1.00      0.82      0.90        11
#                            33_medeu       0.86      1.00      0.92        12
#                              34_ges       0.80      1.00      0.89        12
#          35_vitrina_s_ukrasheniyami       0.00      0.00      0.00        12
#                   36_gobelen_derevo       1.00      1.00      1.00        50
#                 37_gobelen_shahmati       0.92      1.00      0.96        45
#                  38_gobelen_krasniy       1.00      0.58      0.74        12
#               39_loshadki_na_jaylau       0.83      1.00      0.91        29
#                     3_chernaya_vaza       0.82      0.88      0.85        32
#                    40_Abishev_klich       0.90      0.86      0.88        22
#                 41_Aytbayev_schaste       0.97      1.00      0.98        31
#            42_Ahmetov_kompoziciya_4       0.80      0.93      0.86        30
#         43_Dosmogambetov_Suleymenov       0.65      0.75      0.70        20
#                  44_Esenbayev_Saule       0.65      0.59      0.62        22
#            45_Esirkeev_zvuki_kobiza       0.93      0.86      0.89        29
#                46_Jumabay_tri_mecha       0.77      0.69      0.73        29
#                48_Mullashev_triptih       0.88      0.81      0.85        37
#              49_Prokopeva_Sulemenov       0.70      0.88      0.78        26
#                           4_saukele       0.96      1.00      0.98        26
#             50_Sydyhanov_verbludica       0.90      0.96      0.93        27
#                 5_barashki_pasutsya       0.94      1.00      0.97        32
#                      6_vaza_otdelno       0.80      1.00      0.89         8
#                             7_halat       0.91      0.83      0.87        12
#               8_cvetushaya_yablonya       0.00      0.00      0.00         4
#                   9_burdyuk_otdelno       0.89      0.67      0.76        12
#
#                            accuracy                           0.87      1361
#                           macro avg       0.84      0.84      0.84      1361
#                        weighted avg       0.86      0.87      0.86      1361
# Mean Average Precision at IoU=0.5: 0.9006
# Mean Average Precision at IoU=0.5:0.95: 0.9184
