# %% [markdown]
# # Connect Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dataset_path ="/content/drive/MyDrive/Colab_Notebooks/museum/train_dataset"

print("Dataset path exists:", os.path.exists(dataset_path))
print("Folders inside dataset:", os.listdir(dataset_path) if os.path.exists(dataset_path) else "Path not found")
# Out:
# Dataset path exists: True
# Folders inside dataset: ['13_dombri', '15_sedlo2', '12_sandyk1', '14_sedlo1', '16_kobiz_vaza_gobelen', '10_posuda_dlya_kumisa', '20_yarkiy_gobelen_ledi', '17_gobelen_ornament_alasha', '19_fancy_vaza', '21_mujchina_s_mechom', '30_senokos', '37_gobelen_shahmati', '26_berkutchi_s_ptichey', '39_loshadki_na_jaylau', '25_voylok_na_kruge_abstract', '28_shokan_sidit', '29_vesna_jaylau_zagatovka_productov', '22_jambyl', '36_gobelen_derevo', '27_turksib', '48_Mullashev_triptih', '4_saukele', '5_barashki_pasutsya', '50_Sydyhanov_verbludica', '45_Esirkeev_zvuki_kobiza', '41_Aytbayev_schaste', '3_chernaya_vaza', '2_tri_skulpturi_s_sharami', '0_verblyud_skulptura', '1_barashek', '40_Abishev_klich', '42_Ahmetov_kompoziciya_4', '24_dekorativniyi_vazi_vmeste', '43_Dosmogambetov_Suleymenov', '44_Esenbayev_Saule', '46_Jumabay_tri_mecha', '49_Prokopeva_Sulemenov', '6_vaza_otdelno', '7_halat', '8_cvetushaya_yablonya', '9_burdyuk_otdelno', '32_mujchina_s_gazetoy', '18_ukrasheniya', '31_gori_i_voda', '23_revolyuchiya_v_aule', '38_gobelen_krasniy', '33_medeu', '35_vitrina_s_ukrasheniyami', '34_ges', '47_Kazaryan_semya']

# %%
for class_folder in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_folder)
    if os.path.isdir(class_path):
        print(f"Class: {class_folder}, Images: {len(os.listdir(class_path))}")
# Out:
# Class: 13_dombri, Images: 197
# Class: 15_sedlo2, Images: 114
# Class: 12_sandyk1, Images: 116
# Class: 14_sedlo1, Images: 140
# Class: 16_kobiz_vaza_gobelen, Images: 170
# Class: 10_posuda_dlya_kumisa, Images: 202
# Class: 20_yarkiy_gobelen_ledi, Images: 185
# Class: 17_gobelen_ornament_alasha, Images: 150
# Class: 19_fancy_vaza, Images: 193
# Class: 21_mujchina_s_mechom, Images: 159
# Class: 30_senokos, Images: 136
# Class: 37_gobelen_shahmati, Images: 200
# Class: 26_berkutchi_s_ptichey, Images: 136
# Class: 39_loshadki_na_jaylau, Images: 148
# Class: 25_voylok_na_kruge_abstract, Images: 190
# Class: 28_shokan_sidit, Images: 141
# Class: 29_vesna_jaylau_zagatovka_productov, Images: 109
# Class: 22_jambyl, Images: 150
# Class: 36_gobelen_derevo, Images: 202
# Class: 27_turksib, Images: 113
# Class: 48_Mullashev_triptih, Images: 201
# Class: 4_saukele, Images: 124
# Class: 5_barashki_pasutsya, Images: 142
# Class: 50_Sydyhanov_verbludica, Images: 191
# Class: 45_Esirkeev_zvuki_kobiza, Images: 191
# Class: 41_Aytbayev_schaste, Images: 198
# Class: 3_chernaya_vaza, Images: 185
# Class: 2_tri_skulpturi_s_sharami, Images: 202
# Class: 0_verblyud_skulptura, Images: 171
# Class: 1_barashek, Images: 189
# Class: 40_Abishev_klich, Images: 177
# Class: 42_Ahmetov_kompoziciya_4, Images: 194
# Class: 24_dekorativniyi_vazi_vmeste, Images: 201
# Class: 43_Dosmogambetov_Suleymenov, Images: 170
# Class: 44_Esenbayev_Saule, Images: 174
# Class: 46_Jumabay_tri_mecha, Images: 191
# Class: 49_Prokopeva_Sulemenov, Images: 184
# Class: 6_vaza_otdelno, Images: 78
# Class: 7_halat, Images: 110
# Class: 8_cvetushaya_yablonya, Images: 40
# Class: 9_burdyuk_otdelno, Images: 107
# Class: 32_mujchina_s_gazetoy, Images: 107
# Class: 18_ukrasheniya, Images: 164
# Class: 31_gori_i_voda, Images: 98
# Class: 23_revolyuchiya_v_aule, Images: 105
# Class: 38_gobelen_krasniy, Images: 111
# Class: 33_medeu, Images: 105
# Class: 35_vitrina_s_ukrasheniyami, Images: 110
# Class: 34_ges, Images: 109
# Class: 47_Kazaryan_semya, Images: 142

# %% [markdown]
# # ConvNeXtTiny

# %%
import os
import random
import shutil
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageEnhance
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.applications import ConvNeXtTiny
from keras import layers, models, regularizers
from keras.optimizers import Adam
from keras.applications.convnext import preprocess_input
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, average_precision_score, f1_score

# Параметры
batch_size = 16
img_size = (224, 224)
epochs = 20
data_path ="/content/drive/MyDrive/Colab_Notebooks/museum/train_dataset"

# Проверка и балансировка классов
class_counts = {}
for class_name in os.listdir(data_path):
    class_path = os.path.join(data_path, class_name)
    if os.path.isdir(class_path):
        class_counts[class_name] = len(os.listdir(class_path))

# Cортируем классы
sorted_classes = sorted(class_counts.items(), key=lambda x: int(x[0].split("_")[0]))

print("Распределение классов:")
for class_name, count in sorted_classes:
    print(f"{class_name}: {count}")

# Генератор данных
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)

train_generator = train_datagen.flow_from_directory(
    data_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='training',
    shuffle=True
)

validation_generator = train_datagen.flow_from_directory(
    data_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='sparse',
    subset='validation',
    shuffle=False
)

num_classes = len(train_generator.class_indices)

# Label encoding
label_encoder = LabelEncoder()

# Используем ConvNeXt-Tiny
base_model = ConvNeXtTiny(include_top=False, input_shape=(img_size[0], img_size[1], 3), weights='imagenet')
base_model.trainable = True

# Размораживаем только верхние 50 слоёв
for layer in base_model.layers[:-50]:
    layer.trainable = False

# Построение модели
model = models.Sequential([
    base_model,
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.8),
    layers.Dense(num_classes, activation='softmax', kernel_regularizer=regularizers.l2(0.01))
])

# Компиляция модели
model.compile(
    optimizer=Adam(learning_rate=2e-4),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# Callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

# Обучение модели
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[reduce_lr, early_stopping]
)

# Сохранение модели
keras_model_path = "/content/drive/MyDrive/Colab_Notebooks/museum/exhibit_recognition_model_convnext_tiny.keras"
model.save(keras_model_path)
print(f"Модель сохранена в формате Keras: {keras_model_path}")

# Конвертация модели в TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Сохранение TFLite модели
tflite_model_path = "/content/drive/MyDrive/Colab_Notebooks/museum/exhibit_recognition_model_convnext_tiny.tflite"
with open(tflite_model_path, "wb") as f:
    f.write(tflite_model)

print(f"Модель успешно сохранена в формате TFLite: {tflite_model_path}")

# Вычисление метрик на валидационном наборе
y_true = validation_generator.classes
y_pred_probs = model.predict(validation_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix (нормализованная)
cm = confusion_matrix(y_true, y_pred, normalize='true')
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=False, cmap='Blues')
plt.title("Confusion Matrix Normalized")
plt.xlabel("True")
plt.ylabel("Predicted")
plt.show()

# Precision, Recall, F1-score
report = classification_report(y_true, y_pred, target_names=list(class_indices.keys()))
print(report)

# F1-Confidence Curve
confidence_levels = np.linspace(0, 1, 100)
f1_scores = []

for conf in confidence_levels:
    filtered_preds = np.where(y_pred_probs.max(axis=1) >= conf, y_pred, -1)
    f1 = f1_score(y_true, filtered_preds, average='macro', zero_division=0)
    f1_scores.append(f1)

plt.figure(figsize=(8, 6))
plt.plot(confidence_levels, f1_scores, label=f'F1-score (max {max(f1_scores):.2f} at {confidence_levels[np.argmax(f1_scores)]:.3f})', color='blue')
plt.xlabel("Confidence")
plt.ylabel("F1-score")
plt.title("F1-Confidence Curve")
plt.legend()
plt.show()

# Mean Average Precision at IoU=0.5 и IoU=0.5:0.95
average_precisions = []
for i in range(num_classes):
    precision, recall, _ = precision_recall_curve(y_true == i, y_pred_probs[:, i])
    ap = average_precision_score(y_true == i, y_pred_probs[:, i])
    average_precisions.append(ap)

map_50 = np.mean(average_precisions)
map_50_95 = np.mean([ap for ap in average_precisions if ap > 0.05])  # Исключаем слишком малые значения

print(f"Mean Average Precision at IoU=0.5: {map_50:.4f}")
print(f"Mean Average Precision at IoU=0.5:0.95: {map_50_95:.4f}")
# Out:
# Распределение классов:
# 0_verblyud_skulptura: 171
# 1_barashek: 189
# 2_tri_skulpturi_s_sharami: 202
# 3_chernaya_vaza: 185
# 4_saukele: 124
# 5_barashki_pasutsya: 142
# 6_vaza_otdelno: 78
# 7_halat: 110
# 8_cvetushaya_yablonya: 40
# 9_burdyuk_otdelno: 107
# 10_posuda_dlya_kumisa: 202
# 12_sandyk1: 116
# 13_dombri: 197
# 14_sedlo1: 140
# 15_sedlo2: 114
# 16_kobiz_vaza_gobelen: 170
# 17_gobelen_ornament_alasha: 150
# 18_ukrasheniya: 164
# 19_fancy_vaza: 193
# 20_yarkiy_gobelen_ledi: 185
# 21_mujchina_s_mechom: 159
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878885776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878886736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878886352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878889808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378878886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879284432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879288272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879289616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879290768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879290192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879292304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879291344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879293072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879289040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879293264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879294800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879295376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879294032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879292112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879296528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139378879297104: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Модель успешно сохранена в формате TFLite: /content/drive/MyDrive/Colab_Notebooks/museum/exhibit_recognition_model_convnext_tiny.tflite
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 49s 458ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e429a491434f> in <cell line: 0>()
#     139
#     140 # Precision, Recall, F1-score
# --> 141 report = classification_report(y_true, y_pred, target_names=list(class_indices.keys()))
#     142 print(report)
#     143
#
# NameError: name 'class_indices' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion Matrix (нормализованная)
cm = confusion_matrix(y_true, y_pred, normalize='true')
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=False, cmap='Blues')
plt.title("Confusion Matrix Normalized")
plt.xlabel("True")
plt.ylabel("Predicted")
plt.show()

# Precision, Recall, F1-score
report = classification_report(y_true, y_pred, target_names=list(class_indices.keys()))
print(report)

# F1-Confidence Curve
confidence_levels = np.linspace(0, 1, 100)
f1_scores = []

for conf in confidence_levels:
    filtered_preds = np.where(y_pred_probs.max(axis=1) >= conf, y_pred, -1)
    f1 = f1_score(y_true, filtered_preds, average='macro', zero_division=0)
    f1_scores.append(f1)

plt.figure(figsize=(8, 6))
plt.plot(confidence_levels, f1_scores, label=f'F1-score (max {max(f1_scores):.2f} at {confidence_levels[np.argmax(f1_scores)]:.3f})', color='blue')
plt.xlabel("Confidence")
plt.ylabel("F1-score")
plt.title("F1-Confidence Curve")
plt.legend()
plt.show()

# Mean Average Precision at IoU=0.5 и IoU=0.5:0.95
average_precisions = []
for i in range(num_classes):
    precision, recall, _ = precision_recall_curve(y_true == i, y_pred_probs[:, i])
    ap = average_precision_score(y_true == i, y_pred_probs[:, i])
    average_precisions.append(ap)

map_50 = np.mean(average_precisions)
map_50_95 = np.mean([ap for ap in average_precisions if ap > 0.05])  # Исключаем слишком малые значения

print(f"Mean Average Precision at IoU=0.5: {map_50:.4f}")
print(f"Mean Average Precision at IoU=0.5:0.95: {map_50_95:.4f}")
# Out:
#                                      precision    recall  f1-score   support
#
#                0_verblyud_skulptura       0.94      0.85      0.89        34
#               10_posuda_dlya_kumisa       0.73      1.00      0.84        40
#                          12_sandyk1       1.00      1.00      1.00        23
#                           13_dombri       1.00      1.00      1.00        39
#                           14_sedlo1       1.00      1.00      1.00        28
#                           15_sedlo2       1.00      1.00      1.00        22
#               16_kobiz_vaza_gobelen       1.00      1.00      1.00        34
#          17_gobelen_ornament_alasha       1.00      1.00      1.00        30
#                      18_ukrasheniya       0.97      1.00      0.98        32
#                       19_fancy_vaza       1.00      1.00      1.00        38
#                          1_barashek       0.97      0.76      0.85        37
#              20_yarkiy_gobelen_ledi       1.00      1.00      1.00        37
#                21_mujchina_s_mechom       1.00      1.00      1.00        31
#                           22_jambyl       1.00      1.00      1.00        30
#              23_revolyuchiya_v_aule       1.00      1.00      1.00        21
#        24_dekorativniyi_vazi_vmeste       0.90      0.95      0.93        40
#         25_voylok_na_kruge_abstract       1.00      1.00      1.00        38
#              26_berkutchi_s_ptichey       1.00      1.00      1.00        27
#                          27_turksib       1.00      1.00      1.00        22
#                     28_shokan_sidit       1.00      1.00      1.00        28
# 29_vesna_jaylau_zagatovka_productov       1.00      1.00      1.00        21
#           2_tri_skulpturi_s_sharami       0.97      0.82      0.89        40
#                          30_senokos       1.00      1.00      1.00        27
#                      31_gori_i_voda       0.95      0.95      0.95        19
#               32_mujchina_s_gazetoy       1.00      1.00      1.00        21
#                            33_medeu       0.95      1.00      0.98        21
#                              34_ges       1.00      1.00      1.00        21
#          35_vitrina_s_ukrasheniyami       1.00      0.91      0.95        22
#                   36_gobelen_derevo       1.00      1.00      1.00        40
#                 37_gobelen_shahmati       1.00      1.00      1.00        40
#                  38_gobelen_krasniy       1.00      1.00      1.00        22
#               39_loshadki_na_jaylau       1.00      1.00      1.00        29
#                     3_chernaya_vaza       0.95      0.95      0.95        37
#                    40_Abishev_klich       1.00      0.91      0.96        35
#                 41_Aytbayev_schaste       1.00      1.00      1.00        39
#            42_Ahmetov_kompoziciya_4       0.89      0.87      0.88        38
#         43_Dosmogambetov_Suleymenov       1.00      0.91      0.95        34
#                  44_Esenbayev_Saule       1.00      0.97      0.99        34
#            45_Esirkeev_zvuki_kobiza       1.00      1.00      1.00        38
#                46_Jumabay_tri_mecha       0.95      0.97      0.96        38
#                   47_Kazaryan_semya       0.93      0.96      0.95        28
#                48_Mullashev_triptih       0.90      0.93      0.91        40
#              49_Prokopeva_Sulemenov       0.89      0.94      0.92        36
#                           4_saukele       0.96      1.00      0.98        24
#             50_Sydyhanov_verbludica       0.95      1.00      0.97        38
#                 5_barashki_pasutsya       1.00      1.00      1.00        28
#                      6_vaza_otdelno       1.00      1.00      1.00        15
#                             7_halat       1.00      1.00      1.00        22
#               8_cvetushaya_yablonya       1.00      0.88      0.93         8
#                   9_burdyuk_otdelno       0.86      0.90      0.88        21
#
#                            accuracy                           0.97      1507
#                           macro avg       0.97      0.97      0.97      1507
#                        weighted avg       0.97      0.97      0.97      1507
# Mean Average Precision at IoU=0.5: 0.9914
# Mean Average Precision at IoU=0.5:0.95: 0.9914

# %%
class_indices = train_generator.class_indices
print("Class indices:", class_indices)

# Инвертируем словарь
inverted_class_indices = {v: k for k, v in class_indices.items()}

# Предобработка изображения
def preprocess_image(image_path):
    img = load_img(image_path, target_size=img_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

# Проход по всем изображениям в папке_
image_folder = "/content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza"
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if os.path.isfile(os.path.join(image_folder, f))]

for image_path in image_files:
    preprocessed_image = preprocess_image(image_path)
    predictions = model.predict(preprocessed_image)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class = inverted_class_indices.get(predicted_class_index, "Unknown")
    print(f"Изображение: {image_path} | Предсказанный класс: {predicted_class}")
# Out:
# Class indices: {'0_verblyud_skulptura': 0, '10_posuda_dlya_kumisa': 1, '12_sandyk1': 2, '13_dombri': 3, '14_sedlo1': 4, '15_sedlo2': 5, '16_kobiz_vaza_gobelen': 6, '17_gobelen_ornament_alasha': 7, '18_ukrasheniya': 8, '19_fancy_vaza': 9, '1_barashek': 10, '20_yarkiy_gobelen_ledi': 11, '21_mujchina_s_mechom': 12, '22_jambyl': 13, '23_revolyuchiya_v_aule': 14, '24_dekorativniyi_vazi_vmeste': 15, '25_voylok_na_kruge_abstract': 16, '26_berkutchi_s_ptichey': 17, '27_turksib': 18, '28_shokan_sidit': 19, '29_vesna_jaylau_zagatovka_productov': 20, '2_tri_skulpturi_s_sharami': 21, '30_senokos': 22, '31_gori_i_voda': 23, '32_mujchina_s_gazetoy': 24, '33_medeu': 25, '34_ges': 26, '35_vitrina_s_ukrasheniyami': 27, '36_gobelen_derevo': 28, '37_gobelen_shahmati': 29, '38_gobelen_krasniy': 30, '39_loshadki_na_jaylau': 31, '3_chernaya_vaza': 32, '40_Abishev_klich': 33, '41_Aytbayev_schaste': 34, '42_Ahmetov_kompoziciya_4': 35, '43_Dosmogambetov_Suleymenov': 36, '44_Esenbayev_Saule': 37, '45_Esirkeev_zvuki_kobiza': 38, '46_Jumabay_tri_mecha': 39, '47_Kazaryan_semya': 40, '48_Mullashev_triptih': 41, '49_Prokopeva_Sulemenov': 42, '4_saukele': 43, '50_Sydyhanov_verbludica': 44, '5_barashki_pasutsya': 45, '6_vaza_otdelno': 46, '7_halat': 47, '8_cvetushaya_yablonya': 48, '9_burdyuk_otdelno': 49}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_13_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_103_crop_0.jpg | Предсказанный класс: 47_Kazaryan_semya
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_104_crop_0.jpg | Предсказанный класс: 47_Kazaryan_semya
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_10_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_100_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_22_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_56_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_28_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_27_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_57_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_6_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_34_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_18_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_48_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_24_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_66_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_31_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_59_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_15_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_26_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_58_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_29_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_55_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_37_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_79_crop_0.jpg | Предсказанный класс: 42_Ahmetov_kompoziciya_4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_8_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_70_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_94_crop_0.jpg | Предсказанный класс: 46_Jumabay_tri_mecha
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_1_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_78_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_77_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_101_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_10_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_76_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_105_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_82_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_96_crop_0.jpg | Предсказанный класс: 46_Jumabay_tri_mecha
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_67_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_75_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_72_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_87_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_85_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_19_crop_0.jpg | Предсказанный класс: 44_Esenbayev_Saule
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_15_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_13_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_38_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_23_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_58_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_40_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_56_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_36_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_57_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_27_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_41_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_6_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_22_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_34_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_50_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_33_crop_0.jpg | Предсказанный класс: 3_chernaya_vaza
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1_4_crop_0.jpg | Предсказанный класс: 46_Jumabay_tri_mecha
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Изображение: /content/drive/MyDrive/Colab_Notebooks/museum/train_dataset/3_chernaya_vaza/3_1